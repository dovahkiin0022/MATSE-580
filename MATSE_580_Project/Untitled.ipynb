# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from pycalphad import Database, calculate, equilibrium, variables as v
from PT import PT_phase_diagram
from binary_helpers import plot_convex_hull
# Out:
# D:\Anaconda\lib\site-packages\distributed\config.py:63: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config.update(yaml.load(text))

# %%
db_mov = Database('mov_bra.tdb')

# %%
print(sorted(db_mov.elements))
# Out:
# ['/-', 'MO', 'V', 'VA']

# %%
print(sorted(db_mov.phases))
# Out:
# ['BCC_A2', 'LIQUID']

# %% [markdown]
# ### Molar Gibbs free energy for Mo

# %%
bcc_GM = calculate(db_mov, ['MO', 'VA'], 'BCC_A2', P=101325, T=(300, 5000, 10), N=1,output='GM')
liquid_GM = calculate(db_mov, ['MO', 'VA'], 'LIQUID', P=101325, T=(300, 5000, 10), N=1,output='GM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_GM.T, bcc_GM.GM.squeeze(), label='BCC_A2')
plt.plot(liquid_GM.T, liquid_GM.GM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("GM [J/mol-atom]")
plt.legend()

# %% [markdown]
# ### Molar Heat capacity for Mo

# %%
bcc_CPM = calculate(db_mov, ['MO', 'VA'], 'BCC_A2', P=101325, T=(300, 5000, 10), N=1,output='CPM')
liquid_CPM = calculate(db_mov, ['MO', 'VA'], 'LIQUID', P=101325, T=(300, 5000, 10), N=1,output='CPM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_CPM.T, bcc_CPM.CPM.squeeze(), label='BCC_A2')
plt.plot(liquid_CPM.T, liquid_CPM.CPM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("CPM [J/K/mol-atom]")
plt.legend()

# %% [markdown]
# ### Molar entropy of Mo

# %%
bcc_SM = calculate(db_mov, ['MO', 'VA'], 'BCC_A2', P=101325, T=(300, 5000, 10), N=1,output='SM')
liquid_SM = calculate(db_mov, ['MO', 'VA'], 'LIQUID', P=101325, T=(300, 5000, 10), N=1,output='SM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_SM.T, bcc_SM.SM.squeeze(), label='BCC_A2')
plt.plot(liquid_SM.T, liquid_SM.SM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("CPM [J/K/mol-atom]")
plt.legend()

# %% [markdown]
# ### Molar enthalpy of Mo

# %%
bcc_HM = calculate(db_mov, ['MO', 'VA'], 'BCC_A2', P=101325, T=(300, 5000, 10), N=1,output='HM')
liquid_HM = calculate(db_mov, ['MO', 'VA'], 'LIQUID', P=101325, T=(300, 5000, 10), N=1,output='HM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_HM.T, bcc_HM.HM.squeeze(), label='BCC_A2')
plt.plot(liquid_HM.T, liquid_HM.HM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("CPM [J/K/mol-atom]")
plt.legend()

# %% [markdown]
# ### Molar Gibbs energy of V

# %%
bcc_GM = calculate(db_mov, ['V', 'VA'], 'BCC_A2', P=101325, T=(300, 4000, 10), N=1,output='GM')
liquid_GM = calculate(db_mov, ['V', 'VA'], 'LIQUID', P=101325, T=(300, 4000, 10), N=1,output='GM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_GM.T, bcc_GM.GM.squeeze(), label='BCC_A2')
plt.plot(liquid_GM.T, liquid_GM.GM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("GM [J/mol-atom]")
plt.legend()

# %% [markdown]
# ### Molar Heat capacity of V

# %%
bcc_CPM = calculate(db_mov, ['V', 'VA'], 'BCC_A2', P=101325, T=(300, 4000, 10), N=1,output='CPM')
liquid_CPM = calculate(db_mov, ['V', 'VA'], 'LIQUID', P=101325, T=(300, 4000, 10), N=1,output='CPM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_CPM.T, bcc_CPM.CPM.squeeze(), label='BCC_A2')
plt.plot(liquid_CPM.T, liquid_CPM.CPM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("CPM [J/K/mol-atom]")
plt.legend()

# %% [markdown]
# ### Molar entropy of V

# %%
bcc_SM = calculate(db_mov, ['V', 'VA'], 'BCC_A2', P=101325, T=(300, 4000, 10), N=1,output='SM')
liquid_SM = calculate(db_mov, ['V', 'VA'], 'LIQUID', P=101325, T=(300, 4000, 10), N=1,output='SM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_SM.T, bcc_SM.SM.squeeze(), label='BCC_A2')
plt.plot(liquid_SM.T, liquid_SM.SM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("CPM [J/K/mol-atom]")
plt.legend()

# %% [markdown]
# ### Molar enthalpy of V

# %%
bcc_HM = calculate(db_mov, ['V', 'VA'], 'BCC_A2', P=101325, T=(300, 4000, 10), N=1,output='HM')
liquid_HM = calculate(db_mov, ['V', 'VA'], 'LIQUID', P=101325, T=(300, 4000, 10), N=1,output='HM')

# Squeeze is required because the array corresponding to GM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(bcc_HM.T, bcc_HM.HM.squeeze(), label='BCC_A2')
plt.plot(liquid_HM.T, liquid_HM.HM.squeeze(), label='LIQUID')
plt.xlabel("Temperature [K]")
plt.ylabel("CPM [J/K/mol-atom]")
plt.legend()

# %%
comps = ['MO', 'V', 'VA']
phases = ['LIQUID', 'BCC_A2']

# %%
help(equilibrium)
# Out:
# Help on function equilibrium in module pycalphad.core.equilibrium:
#
# equilibrium(dbf, comps, phases, conditions, output=None, model=None, verbose=False, broadcast=True, calc_opts=None, scheduler=<function get_sync at 0x00000144C22967B8>, parameters=None, **kwargs)
#     Calculate the equilibrium state of a system containing the specified
#     components and phases, under the specified conditions.
#
#     Parameters
#     ----------
#     dbf : Database
#         Thermodynamic database containing the relevant parameters.
#     comps : list
#         Names of components to consider in the calculation.
#     phases : list or dict
#         Names of phases to consider in the calculation.
#     conditions : dict or (list of dict)
#         StateVariables and their corresponding value.
#     output : str or list of str, optional
#         Additional equilibrium model properties (e.g., CPM, HM, etc.) to compute.
#         These must be defined as attributes in the Model class of each phase.
#     model : Model, a dict of phase names to Model, or a seq of both, optional
#         Model class to use for each phase.
#     verbose : bool, optional
#         Print details of calculations. Useful for debugging.
#     broadcast : bool
#         If True, broadcast conditions against each other. This will compute all combinations.
#         If False, each condition should be an equal-length list (or single-valued).
#         Disabling broadcasting is useful for calculating equilibrium at selected conditions,
#         when those conditions don't comprise a grid.
#     calc_opts : dict, optional
#         Keyword arguments to pass to `calculate`, the energy/property calculation routine.
#     scheduler : Dask scheduler, optional
#         Job scheduler for performing the computation.
#         If None, return a Dask graph of the computation instead of actually doing it.
#     parameters : dict, optional
#         Maps SymPy Symbol to numbers, for overriding the values of parameters in the Database.
#
#     Returns
#     -------
#     Structured equilibrium calculation, or Dask graph if scheduler=None.
#
#     Examples
#     --------
#     None yet.

# %%
conditions = {  # mapping of state variable to values
    v.N: 1,
    v.P: 101325,
    # for now, only temperature has a range. If multiple variables have ranges, all combinations are calculated
    v.T: (300, 5000, 10),
}
equil_result = equilibrium(db_mov, ['MO'], ['BCC_A2', 'LIQUID'], conditions, output='HM')

# Squeeze is required because the array corresponding to HM is multidimensional for each T, P, and N where we've calculated the energy
plt.plot(equil_result.T, equil_result.HM.squeeze())
plt.xlabel("Temperature [K]")
plt.ylabel("HM [J/mol-atom]")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-34b9c1deb04a> in <module>
#       5     v.T: (300, 5000, 10),
#       6 }
# ----> 7 equil_result = equilibrium(db_mov, ['MO'], ['BCC_A2', 'LIQUID'], conditions, output='HM')
#       8
#       9 # Squeeze is required because the array corresponding to HM is multidimensional for each T, P, and N where we've calculated the energy
#
# D:\Anaconda\lib\site-packages\pycalphad\core\equilibrium.py in equilibrium(dbf, comps, phases, conditions, output, model, verbose, broadcast, calc_opts, scheduler, parameters, **kwargs)
#     375         properties = delayed(properties.merge, pure=False)(eqcal, inplace=True, compat='equals')
#     376     if scheduler is not None:
# --> 377         properties = dask.compute(properties, get=scheduler)[0]
#     378     properties.attrs['created'] = datetime.utcnow().isoformat()
#     379     if len(kwargs) > 0:
#
# D:\Anaconda\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     204     dsk = collections_to_dsk(variables, optimize_graph, **kwargs)
#     205     keys = [var._keys() for var in variables]
# --> 206     results = get(dsk, keys, **kwargs)
#     207
#     208     results_iter = iter(results)
#
# D:\Anaconda\lib\site-packages\dask\local.py in get_sync(dsk, keys, **kwargs)
#     560     """
#     561     kwargs.pop('num_workers', None)    # if num_workers present, remove it
# --> 562     return get_async(apply_sync, 1, dsk, keys, **kwargs)
#     563
#     564
#
# D:\Anaconda\lib\site-packages\dask\local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     527
#     528                 while state['ready'] and len(state['running']) < num_workers:
# --> 529                     fire_task()
#     530
#     531             succeeded = True
#
# D:\Anaconda\lib\site-packages\dask\local.py in fire_task()
#     502                             args=(key, dumps((dsk[key], data)),
#     503                                   dumps, loads, get_id, pack_exception),
# --> 504                             callback=queue.put)
#     505
#     506             # Seed initial tasks into the thread pool
#
# D:\Anaconda\lib\site-packages\dask\local.py in apply_sync(func, args, kwds, callback)
#     549 def apply_sync(func, args=(), kwds={}, callback=None):
#     550     """ A naive synchronous version of apply_async """
# --> 551     res = func(*args, **kwds)
#     552     if callback is not None:
#     553         callback(res)
#
# D:\Anaconda\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     293         failed = False
#     294     except BaseException as e:
# --> 295         result = pack_exception(e, dumps)
#     296         failed = True
#     297     return key, result, failed
#
# D:\Anaconda\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     288     try:
#     289         task, data = loads(task_info)
# --> 290         result = _execute_task(task, data)
#     291         id = get_id()
#     292         result = dumps((result, id))
#
# D:\Anaconda\lib\site-packages\dask\local.py in _execute_task(arg, cache, dsk)
#     269         func, args = arg[0], arg[1:]
#     270         args2 = [_execute_task(a, cache) for a in args]
# --> 271         return func(*args2)
#     272     elif not ishashable(arg):
#     273         return arg
#
# D:\Anaconda\lib\site-packages\dask\compatibility.py in apply(func, args, kwargs)
#      45     def apply(func, args, kwargs=None):
#      46         if kwargs:
# ---> 47             return func(*args, **kwargs)
#      48         else:
#      49             return func(*args)
#
# D:\Anaconda\lib\site-packages\dask\utils.py in __call__(self, obj, *args, **kwargs)
#     686
#     687     def __call__(self, obj, *args, **kwargs):
# --> 688         return getattr(obj, self.method)(*args, **kwargs)
#     689
#     690     def __reduce__(self):
#
# D:\Anaconda\lib\site-packages\xarray\core\dataset.py in merge(self, other, inplace, overwrite_vars, compat, join, fill_value)
#    3384             If any variables conflict (see ``compat``).
#    3385         """
# -> 3386         _check_inplace(inplace)
#    3387         variables, coord_names, dims = dataset_merge_method(
#    3388             self,
#
# D:\Anaconda\lib\site-packages\xarray\core\utils.py in _check_inplace(inplace)
#      38     if inplace is not None:
#      39         raise TypeError(
# ---> 40             "The `inplace` argument has been removed from xarray. "
#      41             "You can achieve an identical effect with python's standard assignment."
#      42         )
#
# TypeError: The `inplace` argument has been removed from xarray. You can achieve an identical effect with python's standard assignment.
